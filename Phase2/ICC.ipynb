# %%
# -*- coding: utf-8 -*-
import os, time, re
from datetime import datetime
import pandas as pd
from tqdm import tqdm
from langchain.prompts import PromptTemplate
from openai import AzureOpenAI

# ───────────────────────────
# 0. Environment (already set externally)
# ───────────────────────────
os.environ['OPENAI_API_VERSION'] = '2024-02-15-preview'
os.environ['AZURE_OPENAI_ENDPOINT'] = 'https://upappliance.openai.azure.com'
os.environ['AZURE_OPENAI_API_KEY'] = '4gWgDnxVjVaIRQhPJFn2seBhFGhsgfZhpedg6J0lmWDdsltOAlD8JQQJ99AKACYeBjFXJ3w3AAABACOGylYc'
os.environ['AZURE_OPENAI_DEPLOYMENT_NAME'] = "gpt-4o-mini"  # 또는 "up_gpt4o"

# ───────────────────────────
# 1. LLM
# ───────────────────────────
client = AzureOpenAI(
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT'],
    api_key=os.environ['AZURE_OPENAI_API_KEY'],
    api_version=os.environ['OPENAI_API_VERSION']
)
DEPLOYMENT = os.environ['AZURE_OPENAI_DEPLOYMENT_NAME']

# ───────────────────────────
# 2. Prompt
# ───────────────────────────
ICC_PROMPT = PromptTemplate.from_template("""
[System]
당신은 가전제품 고객 피드백을 분류하는 전문가입니다. 아래 제공된 정의와 예시, 분류 규칙을 반드시 준수하여, 각 메시지를 Issues(오류), Complaints(불만), Comments(문의) 중 하나로 정확하게 분류하세요.
ICC_label은 Issues, Complaints, Comments 중 하나로 통일하세요.

[Input]
afterchange: {afterchange}

[기본 분류 기준표]
| ICC_label  | 정의 및 신호 | 실제 예시 |
| ---------- | ------------ | --------- |
| Issues     | 제품 또는 서비스에서 오류, 고장, 기기결함이 발생한 경우. <br> "오류", "고장", "에러", "업데이트 안 됨", "연결 안 됨", "삭제됨" 등 **기술적 문제나 고장을 명확히 언급** | - "앱에서 필터를 재설정하려고 하면 '네트워크를 찾을 수 없음'이라는 오류 메시지가 나옵니다." <br>- "건조기가 시작되지 않고, E31 오류 코드가 표시됩니다." <br>- "워시타워 건조기 업그레이드 완료했는데도 업가전센터 들어가면 같은 항목이 업그레이드로 떠요." <br>- "업데이트할 때마다 연결이 안됩니다. 프로그램 실력이 없으면 그대로 사용하게 해주세요." |
| Comments   | 단순 정보 질문, 기존 기능 문의, 기존 기능 개선 건의. <br> **설명, 의견·요청 또는 질문이 중심** | - "관심 없는 업데이트는 숨길 수 있게 해주세요. 세탁기 알림음도 다양하게 필요 없어요." <br>- "로봇 청소시간에 홈뷰나 리모컨으로 청소구역 설정할 수 있나요?" |
| Complaints | 불만, 불편, 짜증, 실망 등 감정적 표현만 있는 경우. <br> "짜증", "불편하다", "어처구니없다" 등 **감정 중심의 부정적 표현만 있음** | - "쓸데없는 알림 보내지 마세요. 이런 거 때문에 다시는 이 브랜드 안 쓸 거예요." <br>- "설정만 되고 시작/종료 버튼은 직접 눌러야 된다니… 어처구니없는 IoT 기기입니다." |

[결정절차: ISSUES GATE]  ➜ A and B 통과 시 바로 Issues, 미통과 시 아래 2–3단계로 진행
- 조건 A(기술 신호어): ["오류","에러","버그","고장","먹통","튕김","강제 종료","깨짐","오작동","에러코드","연결 안 됨","업데이트/설치 실패"]
- 조건 B(고장 ‘사실’ 서술): **구체 대상 + 비정상/실패의 서술**
  예) “세탁기가 중간에 꺼집니다”
- **주의:** (1) A와 B 모두 만족할 시에만 Issues로 판단.
- (2) 현상 서술만(“업데이트 후 물줄기가 가늘어짐/불편함/고쳐주세요/바꿔주세요/높이조절 요청”)은 Issues 금지.
- (3) 질문·추정형(“~인가요/같아요/추측컨대/아마/같은데/될까요?”)은 Issues 금지(B 불충족으로 간주).

2) Comments(문의) — GATE 미통과이고 **질문/설명/기능건의** 중심
   신호: `?`, "어떻게/왜/가능/되나요/인가요/있나요/알려주세요/방법/설정할 수 있나요", '이런 기능이 있어야할 것 같아요'

3) Complaints(불만) — 위 둘 모두 아니고 **감정·불만 표현** 중심
   신호: "불편/짜증/최악/별로/환불/반품/불매/다시는 안 산다/쓰레기/팔지마라"

[우선순위 규칙]
- Issues ▶ Comments ▶ Complaints
- **ISSUES GATE(A+B) 통과** → Issues
- Issues 미통과 & **질문/설명 요청/기능 개선 요청 중심** → Comments
- 위 둘 다 아니고 **감정·불만 중심** → Complaints

- 혼합문장 처리
아래 두 가지 중 하나로 판단합니다.
| 케이스 | 판단 기준 | ICC_label | 실제 예시 |
| ---------------------------------------- | ------------------------------------------------------------- | ------------------ | --------------------------------------------------------------------------------------------------------------------------------------------- |
| **일반적 불편 어조 + 질문/대처법/이유 요청** | 감정 표현이 있더라도 핵심이 **질문·요청**(기능/정책/이유/대처법)인 경우 | Comments | “버튼이 주황색으로 변해서 불편해요. **원래 파랑색인데 이유가 있나요?**”<br>“제품 업그레이드를 하려는데, **충전이 100%여야만 가능한 이유가 있나요?**”<br>“건조 후 세제통에서 물이 흐를 때 **어떻게 대처하나요?** 불안해서 짜증남” |
| **비속어·직설적 강한 비난/반품·불매 선언 등 전체 문장에서 불만만 표시하거나 불만 강도 매우 강함** | 질문·요청보다 **감정적 비난/거절 의사**가 중심(욕설, “반품/환불/다시는 안 산다”, “팔지 마라” 등) | Complaints | “맨날 세탁건조 돌리고, 추가 다족건조까지 돌려야 하는거 **개스트레스**입니다. 가전은 엘지같은 **개소리** 말고 제대로 좀 만드세요.”<br>“**이딴거 팔지마세요.** 500만원짜리 선풍기입니다. **쓰레기**에요. **다시는 안 삽니다.**” |

[출력 형식]
오직 한 줄만 출력하세요. 추가 텍스트/코드블록 금지.
ICC_label: (Issues 또는 Comments 또는 Complaints)  # 영문 라벨만

[출력 형식]
오직 한 줄만 출력하세요. 추가 텍스트/코드블록 금지.
ICC_label: (Issues 또는 Comments 또는 Complaints)  # 영문 라벨만
""")

# ───────────────────────────
# 3. Utility
# ───────────────────────────
def to_safe_str(v):
    return "" if (pd.isna(v) or v is None) else str(v)

def extract_label(text: str):
    m = re.search(r"ICC_label\s*:\s*([A-Za-z]+)", text)
    return m.group(1).strip() if m else "Unknown"

def azure_chat_call(prompt: str, system_msg: str = "You are an expert classifier.", temperature: float = 0):
    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": prompt},
    ]
    for _ in range(3):
        try:
            resp = client.chat.completions.create(
                model=DEPLOYMENT,
                messages=messages,
                temperature=temperature
            )
            content = resp.choices[0].message.content.strip()
            usage = getattr(resp, "usage", None)
            return content, usage
        except Exception as e:
            print(f"⚠️ Chat error {e}, retrying...")
            time.sleep(2)
    raise RuntimeError("Azure Chat call failed after 3 attempts")

def invoke_with_token(prompt_tmpl: PromptTemplate, inputs: dict, step_name: str):
    prompt = prompt_tmpl.format(**inputs)
    content, usage = azure_chat_call(prompt)
    token_log = {}
    if usage:
        token_log = {
            "step": step_name,
            "total_tokens": usage.total_tokens,
            "prompt_tokens": usage.prompt_tokens,
            "completion_tokens": usage.completion_tokens,
        }
        print(f"💰[{step_name}] total={usage.total_tokens}, prompt={usage.prompt_tokens}, completion={usage.completion_tokens}")
    return {
        "raw": content,
        "label": extract_label(content),
        "token_log": token_log
    }

# ───────────────────────────
# 4. Main
# ───────────────────────────
def main():
    df = pd.read_csv("./ICC_labeled.csv", encoding="utf-8-sig")
    df = df.iloc[:5]
    if "ICC_label" not in df.columns:
        df["ICC_label"] = ""

    token_logs = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        try:
            result = invoke_with_token(
                ICC_PROMPT,
                {"afterchange": to_safe_str(row.get("afterchange", ""))},
                "ICC Classification"
            )
            df.at[idx, "ICC_label"] = result["label"]
            if result["token_log"]:
                token_logs.append(result["token_log"])
        except Exception as e:
            print(f"[{idx}] Error: {e}")
            df.at[idx, "ICC_label"] = "Error"

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    out_csv = f"./ICC_labeled_ver10.csv"
    df.to_csv(out_csv, index=False, encoding="utf-8-sig")

    print(f"✅ Done! Saved to: {out_csv}")

if __name__ == "__main__":
    main()

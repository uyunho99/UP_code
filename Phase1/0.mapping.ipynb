# %%
import os
import glob
import pandas as pd

# 데이터 파일이 있는 폴더 경로
folder_path = '/Users/yunho/Desktop/UP'  # <-- 필요에 따라 경로 수정

# 1. *_removed_rows.csv로 끝나는 파일 합치기
removed_files = glob.glob(os.path.join(folder_path, '*_removed_rows.csv'))
df_removed = pd.concat([pd.read_csv(file) for file in removed_files], ignore_index=True)
print(f"[removed] 파일 개수: {len(removed_files)}, 합친 행 수: {len(df_removed)}")

# 2. *_origin_updated.csv로 끝나는 파일 합치기
origin_updated_files = glob.glob(os.path.join(folder_path, '*_origin_updated.csv'))
df_origin_updated = pd.concat([pd.read_csv(file) for file in origin_updated_files], ignore_index=True)
print(f"[origin_updated] 파일 개수: {len(origin_updated_files)}, 합친 행 수: {len(df_origin_updated)}")

# (원하면) 결과를 파일로 저장
df_removed.to_csv('./all_removed_rows.csv', index=False)
df_origin_updated.to_csv('./all_origin_updated.csv', index=False)
# Out:
# [removed] 파일 개수: 13, 합친 행 수: 575
# [origin_updated] 파일 개수: 14, 합친 행 수: 24323

# %%
import pandas as pd

updated_df = pd.read_csv('./all_origin_updated.csv')
removed_df = pd.read_csv('./all_removed_rows.csv')

len(updated_df), len(removed_df)
# Out:
# (24323, 575)

# %%
24323+575+14
# Out:
# 24912

# %%
import pandas as pd
import re

mapping = {
    "LG ThinQ": [
        "LG application", "LG mobile app", "LG apps", "LG app",
        "application", "app", "ThinkQ", "ThinKQ"
    ],
    "remote controller": ["remote", "remote control", "controller"],
    "error": ["error code", "err code", "fault code", "error", "code error"],
    "alarm": ["alarm", "beep"],  # 'beep alarm' 예외!
    "feature": ["function", "feature"],
    "dispenser": ["dispenser", "water dispenser"],
    "ice dispenser": ["ice maker", "ice dispenser"],
    "Objet Collection": [
    "Objet Collection", "objet collection",     # 최상단: 가장 길고 구체적인 것
    "Objet C", "objet C",
    "Objet", "objet"
    ],
    "messenger": ["Kakaotalk", "Kakao talk", "messenger"],
    "washer": ["Washing machine"],
    "display": ["display", "screen"],
}

def expand_keyword_variants(word):
    variants = set()
    variants.add(word)
    variants.add(word.upper())
    variants.add(word.lower())
    variants.add(word.title())
    base = word.replace(' ', '')
    variants.add(base)
    variants.add(base.upper())
    variants.add(base.lower())
    variants.add(base.title())
    return variants

expanded_replace_dict = {}
for rep, words in mapping.items():
    for word in words:
        if word != "beep alarm":
            for variant in expand_keyword_variants(word):
                expanded_replace_dict[variant] = rep

def map_summary(text):
    if pd.isnull(text):
        return text
    text = re.sub(r'\bbeep alarm\b', '__BEEP_ALARM__', text, flags=re.IGNORECASE)
    # 긴 단어 먼저 매핑(부분 매칭 방지)
    for key in sorted(expanded_replace_dict, key=len, reverse=True):
        pattern = r'\b' + re.escape(key) + r'\b'
        text = re.sub(pattern, expanded_replace_dict[key], text)
    text = text.replace('__BEEP_ALARM__', 'beep alarm')
    return text

def extract_matched_terms(text):
    if pd.isnull(text):
        return []
    found_terms = []
    temp = re.sub(r'\bbeep alarm\b', '', text, flags=re.IGNORECASE)
    for key in expanded_replace_dict:
        pattern = r'\b' + re.escape(key) + r'\b'
        if re.search(pattern, temp):
            found_terms.append(key)
    return found_terms

# 사용 예시
file_path = "./all_origin_updated.csv"
df = pd.read_csv(file_path)

df['mapped_summary'] = df['generated_summary'].apply(map_summary)
df['matched_terms'] = df['generated_summary'].apply(extract_matched_terms)

mapped_rows = df[df['matched_terms'].apply(len) > 0]
print(len(mapped_rows), "rows with mapped terms found.")
# Out:
# 11653 rows with mapped terms found.

# %%
# DataFrame을 CSV로 저장
df.to_csv('all_origin_updated_mapped.csv', index=False, encoding='utf-8-sig')
len(df)
# Out:
# 24323

# %%
# 8. 결과 샘플 확인
mapped_rows[['generated_summary', 'mapped_summary', 'matched_terms']]
# Out:
#                                       generated_summary  \
# 12    The user suggests a feature to schedule lighti...
# 14    The user suggests that the app should send an ...
# 16    The user suggests having a feature that allows...
# 21    The user suggests adding a feature that allows...
# 23    The user suggests displaying the current tempe...
# ...                                                 ...
# 3193  The user suggests upgrading the refrigerator t...
# 3194  The user suggests changing the refrigerator's ...
# 3196  The user suggests creating a feature that allo...
# 3203  The user suggests adding the "fermentation und...
# 3204  The user suggests changing the time until the ...
#
#                                          mapped_summary     matched_terms
# 12    The user suggests a feature to schedule lighti...         [feature]
# 14    The user suggests that the LG ThinQ should sen...  [app, operation]
# 16    The user suggests having a feature that allows...         [feature]
# 21    The user suggests adding a feature that allows...         [feature]
# 23    The user suggests displaying the current tempe...             [app]
# ...                                                 ...               ...
# 3193  The user suggests upgrading the refrigerator t...         [display]
# 3194  The user suggests changing the refrigerator's ...        [function]
# 3196  The user suggests creating a feature that allo...         [feature]
# 3203  The user suggests adding the "fermentation und...         [feature]
# 3204  The user suggests changing the time until the ...           [alarm]
#
# [1717 rows x 3 columns]

# %%
# 매핑된 terms들의 전체 빈도(출현 횟수) 집계
from collections import Counter

# matched_terms는 리스트이므로 전체 펼쳐서 집계해야 함
all_terms = [term for terms in df['matched_terms'] if isinstance(terms, list) for term in terms]
term_counts = Counter(all_terms)

# 결과를 DataFrame으로 보기 좋게 정리
term_count_df = pd.DataFrame(term_counts.items(), columns=['matched_term', 'count']).sort_values('count', ascending=False)
term_count_df
# Out:
#         matched_term  count
# 0            feature    623
# 1                app    396
# 6              alarm    346
# 7             option    220
# 3           function    198
# 11         dispenser    156
# 10         ice maker    104
# 13   water dispenser     99
# 4            display     77
# 12     ice dispenser     33
# 21             Objet     27
# 22             objet     27
# 2          operation     19
# 17            screen     16
# 8               menu     14
# 16            remote     11
# 14              beep      8
# 18       application      5
# 5             LG app      5
# 19   Washing machine      4
# 9              error      3
# 23  Objet Collection      3
# 24  objet collection      3
# 20    remote control      2
# 25         Kakaotalk      2
# 15        controller      1

# %%
# 매핑된 terms들의 전체 빈도(출현 횟수) 집계
from collections import Counter

# matched_terms는 리스트이므로 전체 펼쳐서 집계해야 함
all_terms = [term for terms in df['matched_terms'] if isinstance(terms, list) for term in terms]
term_counts = Counter(all_terms)

# 결과를 DataFrame으로 보기 좋게 정리
term_count_df = pd.DataFrame(term_counts.items(), columns=['matched_term', 'count']).sort_values('count', ascending=False)
term_count_df

# %%
def find_rows_by_matched_terms(df, terms):
    mask = df['matched_terms'].apply(lambda x: any(term in x for term in terms) if isinstance(x, list) else False)
    return df.loc[mask, ['generated_summary', 'mapped_summary', 'matched_terms']]

featuer_result = find_rows_by_matched_terms(df, ['feature'])
print(featuer_result.head(10))

app_result = find_rows_by_matched_terms(df, ['app', 'LG ThinQ', 'LG application', 'LG apps', 'LG mobile app'])
print(app_result.head(10))

kakao_result = find_rows_by_matched_terms(df, ['Kakaotalk', 'Kakao talk', 'messenger'])
print(kakao_result.head(10))

objet_result = find_rows_by_matched_terms(df, ['Objet', 'Objet C', 'Objet Collection', 'objet', 'objet collection'])
print(objet_result.head(10))

screen_result = find_rows_by_matched_terms(df, ['display', 'screen'])
print(screen_result.head(10))

alarm_result = find_rows_by_matched_terms(df, ['alarm', 'beep'])
print(alarm_result.head(10))
# Out:
#                                     generated_summary  \
# 12  The user suggests a feature to schedule lighti...
# 16  The user suggests having a feature that allows...
# 21  The user suggests adding a feature that allows...
# 27  The user suggests that all wine cellar product...
# 36  The user suggests that the wine cellar should ...
# 37  The user suggests adding an on/off feature to ...
# 38  The user suggests adding a feature that allows...
# 40  The user suggests improving the process of rec...
# 41  The user suggests having a feature that allows...
# 63  The user suggests including a feature that sen...
#
#                                        mapped_summary            matched_terms
# 12  The user suggests a feature to schedule lighti...                [feature]
# 16  The user suggests having a feature that allows...                [feature]
# 21  The user suggests adding a feature that allows...                [feature]
# 27  The user suggests that all wine cellar product...                [feature]
# 36  The user suggests that the wine cellar should ...                [feature]
# 37  The user suggests adding an on/off feature to ...  [app, feature, display]
# 38  The user suggests adding a feature that allows...                [feature]
# 40  The user suggests improving the process of rec...   [LG app, app, feature]
# 41  The user suggests having a feature that allows...                [feature]
# 63  The user suggests including a feature that sen...                [feature]
#                                     generated_summary  \
# 14  The user suggests that the app should send an ...
# 23  The user suggests displaying the current tempe...
# 37  The user suggests adding an on/off feature to ...
# 39  The user suggests installing a temperature and...
# 40  The user suggests improving the process of rec...
# 48  The user suggests that it would be beneficial ...
# 51  The user suggests adding a method to directly ...
# 53  The user suggests receiving an alarm on the LG...
# 58  The user suggests enabling sorting by wine loc...
# 59  The user suggests taking a photo and registeri...
#
#                                        mapped_summary            matched_terms
# 14  The user suggests that the LG ThinQ should sen...         [app, operation]
# 23  The user suggests displaying the current tempe...                    [app]
# 37  The user suggests adding an on/off feature to ...  [app, feature, display]
# 39  The user suggests installing a temperature and...                    [app]
# 40  The user suggests improving the process of rec...   [LG app, app, feature]
# 48  The user suggests that it would be beneficial ...                    [app]
# 51  The user suggests adding a method to directly ...                    [app]
# 53  The user suggests receiving an alarm on the LG...             [app, alarm]
# 58  The user suggests enabling sorting by wine loc...                    [app]
# 59  The user suggests taking a photo and registeri...                    [app]
#                                       generated_summary  \
# 2339  The user suggests that it would be beneficial ...
# 2710  The user suggests adding notifications via Kak...
#
#                                          mapped_summary  \
# 2339  The user suggests that it would be beneficial ...
# 2710  The user suggests adding notifications via mes...
#
#                   matched_terms
# 2339  [app, feature, Kakaotalk]
# 2710                [Kakaotalk]
#                                       generated_summary  \
# 1428  The user suggests updating the Objet water pur...
# 1533  The user suggests switching to a surface-emitt...
# 1632  The user suggests making it so that the Objet ...
# 1873  The user suggests including a sound control fe...
# 2005  The user suggests integrating a timer alarm fe...
# 2017  The user suggests specifying the water capacit...
# 2021  The user suggests making the lighting of the O...
# 2062  The user suggests that the Magic Space feature...
# 2085  The user suggests that the Objet water purifie...
# 2153  The user suggests that the 2021 Objet water pu...
#
#                                          mapped_summary  \
# 1428  The user suggests updating the Objet Collectio...
# 1533  The user suggests switching to a surface-emitt...
# 1632  The user suggests making it so that the Objet ...
# 1873  The user suggests including a sound control fe...
# 2005  The user suggests integrating a timer alarm fe...
# 2017  The user suggests specifying the water capacit...
# 2021  The user suggests making the lighting of the O...
# 2062  The user suggests that the Magic Space feature...
# 2085  The user suggests that the Objet Collection Co...
# 2153  The user suggests that the 2021 Objet Collecti...
#
#                                           matched_terms
# 1428                                [app, Objet, objet]
# 1533                            [Objet, objet, display]
# 1632                                     [Objet, objet]
# 1873  [alarm, feature, Objet, Objet Collection, obje...
# 2005                     [alarm, feature, Objet, objet]
# 2017                                     [Objet, objet]
# 2021                                     [Objet, objet]
# 2062                            [feature, Objet, objet]
# 2085                                     [Objet, objet]
# 2153                                     [Objet, objet]
#                                      generated_summary  \
# 37   The user suggests adding an on/off feature to ...
# 88   The user suggests that the app should display ...
# 158  The user suggests having a system to check the...
# 168  The user suggests using Critics Scores & Revie...
# 186  The user suggests adding more lighting options...
# 213  The user suggests that the app should display ...
# 277  The user suggests adding a feature to accurate...
# 330  The user suggests adding a feature to the barc...
# 436  The user suggests that they want the color dis...
# 487  The user suggests that the app should clearly ...
#
#                                         mapped_summary  \
# 37   The user suggests adding an on/off feature to ...
# 88   The user suggests that the LG ThinQ should dis...
# 158  The user suggests having a system to check the...
# 168  The user suggests using Critics Scores & Revie...
# 186  The user suggests adding more lighting options...
# 213  The user suggests that the LG ThinQ should dis...
# 277  The user suggests adding a feature to accurate...
# 330  The user suggests adding a feature to the barc...
# 436  The user suggests that they want the color dis...
# 487  The user suggests that the LG ThinQ should cle...
#
#                matched_terms
# 37   [app, feature, display]
# 88            [app, display]
# 158           [app, display]
# 168                [display]
# 186                [display]
# 213           [app, display]
# 277       [feature, display]
# 330       [feature, display]
# 436                [display]
# 487           [app, display]
#                                      generated_summary  \
# 53   The user suggests receiving an alarm on the LG...
# 54   The user suggests that the device should detec...
# 209  The user suggests adding an option to disable ...
# 210  The user suggests a way to turn off the door a...
# 241  The user suggests recording or using a persona...
# 251  The user suggests having an option in the app ...
# 254  The user suggests allowing the door alarm to b...
# 259  The user suggests implementing an alarm system...
# 263  The user suggests adding a functional custom d...
# 264  The user suggests that the refrigerator should...
#
#                                         mapped_summary         matched_terms
# 53   The user suggests receiving an alarm on the LG...          [app, alarm]
# 54   The user suggests that the device should detec...               [alarm]
# 209  The user suggests adding an feature to disable...       [alarm, option]
# 210  The user suggests a way to turn off the door a...               [alarm]
# 241  The user suggests recording or using a persona...               [alarm]
# 251  The user suggests having an feature in the LG ...  [app, alarm, option]
# 254  The user suggests allowing the door alarm to b...               [alarm]
# 259  The user suggests implementing an alarm system...               [alarm]
# 263  The user suggests adding a functional custom d...       [alarm, option]
# 264  The user suggests that the refrigerator should...      [alarm, feature]

# %%
featuer_result.head(5)
# Out:
#                                     generated_summary  \
# 12  The user suggests a feature to schedule lighti...
# 16  The user suggests having a feature that allows...
# 21  The user suggests adding a feature that allows...
# 27  The user suggests that all wine cellar product...
# 36  The user suggests that the wine cellar should ...
#
#                                        mapped_summary matched_terms
# 12  The user suggests a feature to schedule lighti...     [feature]
# 16  The user suggests having a feature that allows...     [feature]
# 21  The user suggests adding a feature that allows...     [feature]
# 27  The user suggests that all wine cellar product...     [feature]
# 36  The user suggests that the wine cellar should ...     [feature]
